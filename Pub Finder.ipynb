# %%
import googlemaps
import folium
import numpy as np
import foursquare

# %%
# List of addresses, provided by pub searchers

adresses = [
    'Rua Harmonia, 722',
    'Avenida Engenheiro Heitor Antonio Eiras Garcia, 587',
    'Rua Engenheiro Mario Pamponet, 349',
    'Rua Castanheiro, 55',
    'Rua Raul Devesa, 251',
    'Rua Cardoso de Almeida, 704'
]

# getting coordinates of searchers, using google maps API
gmap_obj = googlemaps.Client(key='AIzaSyDMMT_Npt60FsmgJPLbLa5mVNf0tauKXqw')
coordinates = []
for adress in adresses:
    geocode_result = gmap_obj.geocode(adress)
    coord = (geocode_result[0]['geometry']['location']['lat'],
             geocode_result[0]['geometry']['location']['lng'])
    coordinates.append(coord)
    
# getting center point
center=(np.average([c[0] for c in coordinates]),np.average([c[1] for c in coordinates]))

# %%
client = foursquare.Foursquare(client_id='YSHD5ULBLK5GCEWR3M3BC4LDTOY00TRLETSLIFEX2AZCLLI1', 
                               client_secret='0DCULLMNUFTIJEA311LIOE31SP03LQK0K5MO5FWL3MTS1YDW')

ll = ','.join([str(center[0]),str(center[1])])
query = 'bar'
srch_result = client.venues.search(params={'query': query, 'll': ll, 'radius': 2000})

# bars_list = [srch_result['venues'][i]['name'] for i in srch_result['venues'][:] ] 
bars_names_list = [srch_result['venues'][i]['name'] for i in range(len(srch_result['venues']))]
bars_coors_list = [(srch_result['venues'][i]['location']['lat'],srch_result['venues'][i]['location']['lng']) for i in range(len(srch_result['venues']))]

# %%
# Plotting Addresses and Center on Map
m = folium.Map(location=[center[0], center[1]],zoom_start=14)

for c in coordinates:
    folium.Marker([c[0],c[1]]).add_to(m)

for index,b in enumerate(bars_coors_list):
    folium.Marker([b[0],b[1]], 
                  icon=folium.Icon(color='green'),
                  popup=bars_names_list[index]).add_to(m)
folium.Marker([center[0],center[1]],icon=folium.Icon(color='red')).add_to(m)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bars_coors_list
# Out:
# [(-23.554093547429222, -46.69416904449463),
#  (-23.552981, -46.687753),
#  (-23.562080581350514, -46.68047723601071),
#  (-23.559886201661865, -46.69281721115112),
#  (-23.55302949396532, -46.68828322510234),
#  (-23.55968895709657, -46.688991256242694),
#  (-23.554162253287878, -46.69162354434805),
#  (-23.55651783871628, -46.69156193733215),
#  (-23.567106977320744, -46.69646121313024),
#  (-23.55660830248407, -46.687380173006446),
#  (-23.55752068850863, -46.68634867550984),
#  (-23.561479025154153, -46.69440151943482),
#  (-23.56018202574843, -46.68570508205349),
#  (-23.556758404317208, -46.68955222923024),
#  (-23.55554486478023, -46.66342150016257),
#  (-23.555402, -46.689133),
#  (-23.55998506852314, -46.68709461691583),
#  (-23.556166713234685, -46.68393436062558),
#  (-23.556196, -46.657941),
#  (-23.558093185573085, -46.68162516805728),
#  (-23.56432577420945, -46.679001294974604),
#  (-23.548903711856877, -46.64256360816825),
#  (-23.56054434335479, -46.6895797895899),
# ...

# %%
srch_result['venues'][0]['location']['lat']
# Out:
# -23.554093547429222
